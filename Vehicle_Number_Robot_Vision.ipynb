# %% [markdown]
# # Vehicle Number Robot Vision

# %% [markdown]
#     - Update Date: 10th March 2018
#
#     - Edited By LEE, Stephen Haesung

# %% [markdown]
#     - Press "shift" + "Enter" to contnue.

# %% [markdown]
# ## Using your USB Camera & Latop Camera for image recognition

# %% [markdown]
# Take a picutre in your robot.

# %%
import os

# %%
os.system('fswebcam -r 1280x720 --no-banner /home/nvidia/Vehicle_Number_Robot_Vision/test_image.jpg')
# Out:
# 0

# %% [markdown]
# ##### How to install a webcam:
#     sudo apt-get install fswebcam   (Linux & Raspberry Pi)
#
#     brew install imagesnap   (Mac)
#
#     sudo apt-get update && sudo apt-get install -y openalpr openalpr-daemon openalpr-utils libopenalpr-dev

# %%
# To plot pretty figures
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
test_image = mpimg.imread(os.path.join("test_image.jpg"))
plt.imshow(test_image)
plt.axis("on")
plt.show()

# %% [markdown]
# # The Result on Terminal:
#
# ## 786P0J	 confidence: 86.1451
# ## 7B6P0J	 confidence: 84.5204
# ## 766P0J	 confidence: 84.0398

# %%
# os.system('alpr -c us test_image.jpg')
os.system('alpr -c eu test_image.jpg')
# Out:
# 0

# %%
# END
